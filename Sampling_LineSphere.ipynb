# %% [markdown]
# # Line & Sphere

# %%
# %run Sampling_Points_Individually.py
import Sampling_Points_Individually as SPI
from Sampling_Points_Individually import *
# Out:
# [[-2.07889335  1.70058576 -1.71730014]
#  [-2.42100654  1.85472086 -1.78375977]
#  [-0.6593202   1.06101364 -1.44153085]
#  ...,
#  [ 0.17822108  0.68366919 -1.2788283 ]
#  [-0.60785406  1.03782617 -1.43153292]
#  [-1.05306011  1.23840857 -1.5180196 ]]
# [NbConvertApp] Converting notebook Sampling_Points_Individually.ipynb to script
# [NbConvertApp] Writing 3496 bytes to Sampling_Points_Individually.py

# %%
import numpy as np
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
from numpy.random import rand
from pylab import figure
# %matplotlib inline

# %% [markdown]
# # Obtaining a translating the scaled version of the line to the surface of the sphere

# %%
#Centre of the Sphere
x=np.array([0,0,0])
#Point on the surface of the sphere
#print(SPI.P[1])
p=(SPI.L[0][0],SPI.L[0][1],SPI.L[0][2])
#print(p)
# vector from centre to point p
l=x-p
#scaling up the vector
Scale_L=5*l
#vector on the sphere
Sphere_L=Scale_L-p
#print(Scale_L)
#random parameters for scaling
parameter = np.transpose(np.random.randn(1000)[np.newaxis])
#Sampling from vector on the sphere
sphere_line=parameter*Sphere_L
#test code: should be equal to 1000
print(len(sphere_line))
# Out:
# 1000

# %% [markdown]
# # Adding the points sampled from the new translated line to the set of points sampled from sphere

# %%
#Coverting to list from numpy array
Sample_L=SPI.L.tolist()
Sample_P=SPI.P.tolist()
Sample_S=SPI.S.tolist()
Sample_LS=Sample_S
#test code: should be equal to 1000
print(len(Sample_LS))


for i in range(len(sphere_line)):
    Sample_LS.append(sphere_line[i])
    #Sample_LS[1].append(Sample_L[i][1])
    #Sample_LS[2].append(Sample_L[i][2])
# Out:
# 1000

# %%
#test code: should be equal to 2000
Sample_LS[1]
len(Sample_LS)
# Out:
# 2000

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
from numpy.random import rand
from pylab import figure


S1=Sample_S# m is an array of (x,y,z) coordinate triplets
L1=sphere_line
#print(LS)
#n=exits_sorted['name']
#print(m)

fig=figure(figsize=(30,15))
##fig = figure()
ax = Axes3D(fig)


for i in range(len(L1)): #plot each point + it's index as text above
 ax.scatter(L1[i][0],L1[i][1],L1[i][2],color='b')
 ax.scatter(S1[i][0],S1[i][1],S1[i][2],color='r')
 #ax.text(m[i][0],m[i][1],m[i][2],  '%s' % (str(i)), size=20, zorder=1,  
 #color='k')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
pyplot.show()

# %% [markdown]
# # Adding another line to the sphere

# %%
#Centre of the Sphere
x=np.array([0,0,0])
#Point on the surface of the sphere
#print(SPI.P[1])
p=(SPI.L1[0][0],SPI.L1[0][1],SPI.L1[0][2])
#print(p)
# vector from centre to point p
l=x-p
#scaling up the vector
Scale_L=5*l
#vector on the sphere
Sphere_L=Scale_L-p
#print(Scale_L)
#random parameters for scaling
parameter = np.transpose(np.random.randn(1000)[np.newaxis])
#Sampling from vector on the sphere
sphere_line1=parameter*Sphere_L
#test code: should be equal to 1000
print(len(sphere_line1))
# Out:
# 1000

# %%
#Coverting to list from numpy array
Sample_L1=SPI.L1.tolist()
Sample_LS1=Sample_LS
#test code: should be equal to 1000
print(len(Sample_LS1))


for i in range(len(sphere_line)):
    Sample_LS1.append(sphere_line[i])
    #Sample_LS[1].append(Sample_L[i][1])
    #Sample_LS[2].append(Sample_L[i][2])
# Out:
# 2000

# %%
len(Sample_LS1)
# Out:
# 3000

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
from numpy.random import rand
from pylab import figure


S1=Sample_S# m is an array of (x,y,z) coordinate triplets
L1=sphere_line
L2=sphere_line1
#print(LS)
#n=exits_sorted['name']
#print(m)

fig=figure(figsize=(30,15))
##fig = figure()
ax = Axes3D(fig)


for i in range(len(L1)):#plot each point + it's index as text above
    ax.scatter(L1[i][0],L1[i][1],L1[i][2],color='b')
    ax.scatter(S1[i][0],S1[i][1],S1[i][2],color='r')
    ax.scatter(L2[i][0],L2[i][1],L2[i][2],color='g')
    
 #ax.text(m[i][0],m[i][1],m[i][2],  '%s' % (str(i)), size=20, zorder=1,  
 #color='k')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
pyplot.show()

# %%
# !jupyter nbconvert --to script Sampling_LineSphere.ipynb
# Out:
# [NbConvertApp] Converting notebook Sampling_LineSphere.ipynb to script
# [NbConvertApp] Writing 3934 bytes to Sampling_LineSphere.py
